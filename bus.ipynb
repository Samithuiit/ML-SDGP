# %%
# !pip install numpy
# !pip install pandas
# !pip install requests
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 978.8 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.7/123.7 kB 2.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 7.1 MB/s eta 0:00:00
# ...

# %%
pip install --upgrade pip
# Out:
# ...
#   Using cached pip-23.0.1-py3-none-any.whl (2.1 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3.1
#     Uninstalling pip-22.3.1:
#       Successfully uninstalled pip-22.3.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1283, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1282 """Send a complete request to the server."""
# -> 1283 self._send_request(method, url, body, headers, encode_chunked)
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1283, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1282 """Send a complete request to the server."""
# -> 1283 self._send_request(method, url, body, headers, encode_chunked)
#
# ...

# %%
import requests
import pandas as pd
import io
url = "https://raw.githubusercontent.com/Samithuiit/ML-SDGP/main/bus_data.csv"
response = requests.get(url)
content = response.content.decode('utf-8')
data = pd.read_csv(io.StringIO(content))
data.head()
# Out:
#          date   time   bus_rides_per_day   distance_km   passengers
# 0  2023-03-01  08:15                   8            20           30  \
# 1  2023-03-01  10:20                   8            20           28
# 2  2023-03-01  12:35                   8            20           32
# 3  2023-03-01  15:10                   8            20           26
# 4  2023-03-01  18:20                   8            20           33
#
#     ride_time_min   income_per_ride   cost_per_ride   profit_per_ride
# 0              40              8000            3500              4500
# 1              35              8500            3600              4900
# 2              42              7900            3550              4350
# 3              45              9000            3700              5300
# 4              38              8100            3550              4550

# %%
data.shape
# Out:
# (56, 9)

# %%
data.isnull()
# Out:
#      date   time   bus_rides_per_day   distance_km   passengers
# 0   False  False               False         False        False  \
# 1   False  False               False         False        False
# 2   False  False               False         False        False
# 3   False  False               False         False        False
# 4   False  False               False         False        False
# 5   False  False               False         False        False
# 6   False  False               False         False        False
# 7   False  False               False         False        False
# 8   False  False               False         False        False
# 9   False  False               False         False        False
# 10  False  False               False         False        False
# 11  False  False               False         False        False
# 12  False  False               False         False        False
# 13  False  False               False         False        False
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                56 non-null     object
#  1    time               56 non-null     object
#  2    bus_rides_per_day  56 non-null     int64
#  3    distance_km        56 non-null     int64
#  4    passengers         56 non-null     int64
#  5    ride_time_min      56 non-null     int64
#  6    income_per_ride    56 non-null     int64
#  7    cost_per_ride      56 non-null     int64
#  8    profit_per_ride    56 non-null     int64
# dtypes: int64(7), object(2)
# memory usage: 4.1+ KB

# %%
data.head(5)
# Out:
#          date   time   bus_rides_per_day   distance_km   passengers
# 0  2023-03-01  08:15                   8            20           30  \
# 1  2023-03-01  10:20                   8            20           28
# 2  2023-03-01  12:35                   8            20           32
# 3  2023-03-01  15:10                   8            20           26
# 4  2023-03-01  18:20                   8            20           33
#
#     ride_time_min   income_per_ride   cost_per_ride   profit_per_ride
# 0              40              8000            3500              4500
# 1              35              8500            3600              4900
# 2              42              7900            3550              4350
# 3              45              9000            3700              5300
# 4              38              8100            3550              4550

# %%
data.corr()['profit_per_ride']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 data.corr()['profit_per_ride']
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/frame.py:1837, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1835 if dtype is not None:
#    1836     dtype = np.dtype(dtype)
# -> 1837 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1838 if result.dtype is not dtype:
#    1839     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
# Drop the date column
data_without_date = data.drop('date', axis=1)

# Calculate the correlation matrix
correlation_matrix = data_without_date.corr()

# Print the correlation coefficients for the profit_per_ride column
print(correlation_matrix['profit_per_ride'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 5
#       2 data_without_date = data.drop('date', axis=1)
#       4 # Calculate the correlation matrix
# ----> 5 correlation_matrix = data_without_date.corr()
#       7 # Print the correlation coefficients for the profit_per_ride column
#       8 print(correlation_matrix['profit_per_ride'])
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/frame.py:1837, in DataFrame.to_numpy(self, dtype, copy, na_value)
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                56 non-null     object
#  1    time               56 non-null     object
#  2    bus_rides_per_day  56 non-null     int64
#  3    distance_km        56 non-null     int64
#  4    passengers         56 non-null     int64
#  5    ride_time_min      56 non-null     int64
#  6    income_per_ride    56 non-null     int64
#  7    cost_per_ride      56 non-null     int64
#  8    profit_per_ride    56 non-null     int64
# dtypes: int64(7), object(2)
# memory usage: 4.1+ KB

# %%
data.corr()['profit_per_ride']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 data.corr()['profit_per_ride']
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/frame.py:1837, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1835 if dtype is not None:
#    1836     dtype = np.dtype(dtype)
# -> 1837 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1838 if result.dtype is not dtype:
#    1839     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                56 non-null     datetime64[ns]
#  1    time               56 non-null     object
#  2    bus_rides_per_day  56 non-null     int64
#  3    distance_km        56 non-null     int64
#  4    passengers         56 non-null     int64
#  5    ride_time_min      56 non-null     int64
#  6    income_per_ride    56 non-null     int64
#  7    cost_per_ride      56 non-null     int64
#  8    profit_per_ride    56 non-null     int64
# dtypes: datetime64[ns](1), int64(7), object(1)
# memory usage: 4.1+ KB

# %%
data['time'] = pd.to_datetime(data['date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                56 non-null     datetime64[ns]
#  1    time               56 non-null     object
#  2    bus_rides_per_day  56 non-null     int64
#  3    distance_km        56 non-null     int64
#  4    passengers         56 non-null     int64
#  5    ride_time_min      56 non-null     int64
#  6    income_per_ride    56 non-null     int64
#  7    cost_per_ride      56 non-null     int64
#  8    profit_per_ride    56 non-null     int64
#  9   time                56 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), int64(7), object(1)
# memory usage: 4.5+ KB

# %%
data.corr()['profit_per_ride']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 data.corr()['profit_per_ride']
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/frame.py:1837, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1835 if dtype is not None:
#    1836     dtype = np.dtype(dtype)
# -> 1837 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1838 if result.dtype is not dtype:
#    1839     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
data['time'] = pd.to_numeric(data['time'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                56 non-null     datetime64[ns]
#  1    time               56 non-null     object
#  2    bus_rides_per_day  56 non-null     int64
#  3    distance_km        56 non-null     int64
#  4    passengers         56 non-null     int64
#  5    ride_time_min      56 non-null     int64
#  6    income_per_ride    56 non-null     int64
#  7    cost_per_ride      56 non-null     int64
#  8    profit_per_ride    56 non-null     int64
#  9   time                56 non-null     int64
# dtypes: datetime64[ns](1), int64(8), object(1)
# memory usage: 4.5+ KB

# %%
data.corr()['profit_per_ride']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 data.corr()['profit_per_ride']
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/frame.py:1837, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1835 if dtype is not None:
#    1836     dtype = np.dtype(dtype)
# -> 1837 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1838 if result.dtype is not dtype:
#    1839     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 data['time'] =data['time'].str.replace('','').astype('float32')
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'profit_per_ride'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import requests
import pandas as pd
import io
url = "https://raw.githubusercontent.com/Samithuiit/ML-SDGP/main/bus_data.csv"
response = requests.get(url)
content = response.content.decode('utf-8')
data = pd.read_csv(io.StringIO(content))
data.head()
# Out:
#          date   time   bus_rides_per_day   distance_km   passengers
# 0  2023-03-01   8.15                   8            20           30  \
# 1  2023-03-01  10.20                   8            20           28
# 2  2023-03-01  12.35                   8            20           32
# 3  2023-03-01  15.10                   8            20           26
# 4  2023-03-01  18.20                   8            20           33
#
#     ride_time_min   income_per_ride  cost_per_ride   profit_per_ride
# 0              40            8000.0        3500.00            4500.0
# 1              35            8500.0        3600.00            4900.0
# 2              42            7900.0        3550.00            4350.0
# 3              45            9000.0        3700.00            5300.0
# 4              38            8100.0        3550.00            4550.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                56 non-null     object
#  1    time               56 non-null     float64
#  2    bus_rides_per_day  56 non-null     int64
#  3    distance_km        56 non-null     int64
#  4    passengers         56 non-null     int64
#  5    ride_time_min      56 non-null     int64
#  6    income_per_ride    56 non-null     float64
#  7    cost_per_ride      56 non-null     object
#  8    profit_per_ride    55 non-null     float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 4.1+ KB

# %%
data.corr()['profit_per_ride']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 data.corr()['profit_per_ride']
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/frame.py:1837, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1835 if dtype is not None:
#    1836     dtype = np.dtype(dtype)
# -> 1837 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1838 if result.dtype is not dtype:
#    1839     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                56 non-null     datetime64[ns]
#  1    time               56 non-null     float64
#  2    bus_rides_per_day  56 non-null     int64
#  3    distance_km        56 non-null     int64
#  4    passengers         56 non-null     int64
#  5    ride_time_min      56 non-null     int64
#  6    income_per_ride    56 non-null     int64
#  7    cost_per_ride      56 non-null     int64
#  8    profit_per_ride    56 non-null     int64
#  9   time                56 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(7)
# memory usage: 4.5 KB

# %%
data.corr()['profit_per_ride']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'profit_per_ride'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data.corr()[' profit_per_ride']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 data.corr()['  profit_per_ride']
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/frame.py:1837, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1835 if dtype is not None:
#    1836     dtype = np.dtype(dtype)
# -> 1837 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1838 if result.dtype is not dtype:
#    1839     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                56 non-null     object
#  1    time               56 non-null     float64
#  2    bus_rides_per_day  56 non-null     int64
#  3    distance_km        56 non-null     int64
#  4    passengers         56 non-null     int64
#  5    ride_time_min      56 non-null     int64
#  6    income_per_ride    56 non-null     float64
#  7    cost_per_ride      56 non-null     object
#  8    profit_per_ride    55 non-null     float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 4.1+ KB

# %%
data.corr()
# Out:
#                         date      time   bus_rides_per_day   distance_km
# date                1.000000 -0.147787                 NaN           NaN  \
#  time              -0.147787  1.000000                 NaN           NaN
#  bus_rides_per_day       NaN       NaN                 NaN           NaN
#  distance_km             NaN       NaN                 NaN           NaN
#  passengers         0.436014  0.053591                 NaN           NaN
#  ride_time_min      0.163847 -0.133854                 NaN           NaN
#  income_per_ride   -0.834936  0.099543                 NaN           NaN
#  cost_per_ride      0.835991 -0.051156                 NaN           NaN
#  profit_per_ride    0.374191  0.144734                 NaN           NaN
#
#                      passengers   ride_time_min   income_per_ride
# date                   0.436014        0.163847         -0.834936  \
#  time                  0.053591       -0.133854          0.099543
# ...

# %%
data = data.astype({'bus_rides_per_day': 'float64',
                    'distance_km': 'float64',
                    'passengers': 'float64',
                    'ride_time_min': 'float64',
                    'income_per_ride': 'float64',
                    'cost_per_ride': 'float64',
                    'profit_per_ride': 'float64'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 data = data.astype({'bus_rides_per_day': 'float64',
#       2                     'distance_km': 'float64',
#       3                     'passengers': 'float64',
#       4                     'ride_time_min': 'float64',
#       5                     'income_per_ride': 'float64',
#       6                     'cost_per_ride': 'float64',
#       7                     'profit_per_ride': 'float64'})
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/generic.py:6290, in NDFrame.astype(self, dtype, copy, errors)
#    6288 for col_name in dtype_ser.index:
#    6289     if col_name not in self:
# -> 6290         raise KeyError(
#    6291             "Only a column name can be used for the "
#    6292             "key in a dtype mappings argument. "
# ...

# %%
data['profit_per_ride'] = data['profit_per_ride'].astype('float64')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'profit_per_ride'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data = data.astype({'bus_rides_per_day': 'float64'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 data = data.astype({'bus_rides_per_day': 'float64'})
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/generic.py:6290, in NDFrame.astype(self, dtype, copy, errors)
#    6288 for col_name in dtype_ser.index:
#    6289     if col_name not in self:
# -> 6290         raise KeyError(
#    6291             "Only a column name can be used for the "
#    6292             "key in a dtype mappings argument. "
#    6293             f"'{col_name}' not found in columns."
#    6294         )
#    6296 dtype_ser = dtype_ser.reindex(self.columns, fill_value=None, copy=False)
#    6298 results = []
#
# KeyError: "Only a column name can be used for the key in a dtype mappings argument. 'bus_rides_per_day' not found in columns."

# %%
data = data.astype({
    'bus_rides_per_day': 'float64',
    'distance_km': 'float64',
    'passengers': 'float64',
    'ride_time_min': 'float64',
    'income_per_ride': 'float64',
    'cost_per_ride': 'float64',
    'profit_per_ride': 'float64'
})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 data = data.astype({
#       2     'bus_rides_per_day': 'float64',
#       3     'distance_km': 'float64',
#       4     'passengers': 'float64',
#       5     'ride_time_min': 'float64',
#       6     'income_per_ride': 'float64',
#       7     'cost_per_ride': 'float64',
#       8     'profit_per_ride': 'float64'
#       9 })
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/generic.py:6290, in NDFrame.astype(self, dtype, copy, errors)
#    6288 for col_name in dtype_ser.index:
#    6289     if col_name not in self:
# -> 6290         raise KeyError(
#    6291             "Only a column name can be used for the "
#    6292             "key in a dtype mappings argument. "
#    6293             f"'{col_name}' not found in columns."
#    6294         )
# ...

# %%
data['profit_per_ride'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Workspace/ML/bussession/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'profit_per_ride'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data
# Out:
#           date   time   bus_rides_per_day   distance_km   passengers
# 0   2023-03-01   8.15                   8            20           30  \
# 1   2023-03-01  10.20                   8            20           28
# 2   2023-03-01  12.35                   8            20           32
# 3   2023-03-01  15.10                   8            20           26
# 4   2023-03-01  18.20                   8            20           33
# 5   2023-03-01  20.25                   8            20           31
# 6   2023-03-01  22.40                   8            20           27
# 7   2023-03-01  23.55                   8            20           29
# 8   2023-03-02   8.10                   8            20           32
# 9   2023-03-02  10.25                   8            20           30
# 10  2023-03-02  12.50                   8            20           28
# 11  2023-03-02  15.15                   8            20           31
# 12  2023-03-02  18.30                   8            20           29
# ...

# %%
data
# Out:
#           date   time   bus_rides_per_day   distance_km   passengers
# 0   2023-03-01   8.15                   8            20           30  \
# 1   2023-03-01  10.20                   8            20           28
# 2   2023-03-01  12.35                   8            20           32
# 3   2023-03-01  15.10                   8            20           26
# 4   2023-03-01  18.20                   8            20           33
# 5   2023-03-01  20.25                   8            20           31
# 6   2023-03-01  22.40                   8            20           27
# 7   2023-03-01  23.55                   8            20           29
# 8   2023-03-02   8.10                   8            20           32
# 9   2023-03-02  10.25                   8            20           30
# 10  2023-03-02  12.50                   8            20           28
# 11  2023-03-02  15.15                   8            20           31
# 12  2023-03-02  18.30                   8            20           29
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                56 non-null     object
#  1    time               56 non-null     float64
#  2    bus_rides_per_day  56 non-null     int64
#  3    distance_km        56 non-null     int64
#  4    passengers         56 non-null     int64
#  5    ride_time_min      56 non-null     int64
#  6    income_per_ride    56 non-null     float64
#  7    cost_per_ride      56 non-null     object
#  8    profit_per_ride    55 non-null     float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 4.1+ KB

# %%
data.describe()
# Out:
#             time   bus_rides_per_day   distance_km   passengers
# count  56.000000                56.0          56.0    56.000000  \
# mean   15.130357                 8.0          20.0    32.839286
# std     5.547519                 0.0           0.0     5.496368
# min     5.000000                 8.0          20.0    20.000000
# 25%    10.287500                 8.0          20.0    29.000000
# 50%    15.025000                 8.0          20.0    31.500000
# 75%    20.050000                 8.0          20.0    36.250000
# max    23.550000                 8.0          20.0    45.000000
#
#         ride_time_min   income_per_ride   profit_per_ride
# count       56.000000         56.000000         55.000000
# mean        40.446429       6393.482143       5102.545455
# std          4.343939       2514.293850        725.168482
# min         30.000000       3400.000000       3200.000000
# 25%         37.750000       3496.250000       4550.000000
# ...

# %%
data.columns
# Out:
# Index(['date', ' time', ' bus_rides_per_day', ' distance_km', ' passengers',
#        ' ride_time_min', ' income_per_ride', ' cost_per_ride',
#        ' profit_per_ride'],
#       dtype='object')

# %%
print(data[' passengers'].value_counts())
print(data[' income_per_ride'].value_counts())
# Out:
#  passengers
# 30    7
# 28    5
# 29    5
# 32    4
# 33    4
# 31    4
# 27    4
# 40    3
# 42    3
# 35    2
# 34    2
# 38    2
# 36    2
# 20    1
# 25    1
# 26    1
# 44    1
# 39    1
# 45    1
# 41    1
# 43    1
# 37    1
# Name: count, dtype: int64
#  income_per_ride
# 7900.0    3
# 8100.0    3
# 8600.0    3
# 8000.0    2
# 9100.0    2
# 7000.0    2
# 3525.0    2
# 9400.0    2
# 3470.0    2
# 8400.0    2
# 8700.0    2
# 8800.0    2
# 8200.0    2
# 3435.0    2
# 8500.0    2
# 3510.0    1
# 3430.0    1
# 3515.0    1
# 3400.0    1
# 3460.0    1
# 3465.0    1
# 3555.0    1
# 3445.0    1
# 3485.0    1
# 3475.0    1
# 3550.0    1
# 3500.0    1
# 3425.0    1
# 3455.0    1
# 3480.0    1
# 3505.0    1
# 9700.0    1
# 9600.0    1
# 6500.0    1
# 8900.0    1
# 8300.0    1
# 9000.0    1
# 3520.0    1
# Name: count, dtype: int64

# %%
print(data[' time'].value_counts())
# Out:
#  time
# 23.55    3
# 15.00    3
# 8.00     2
# 10.30    2
# 19.00    2
# 8.10     2
# 13.30    2
# 23.00    2
# 11.45    1
# 17.00    1
# 18.00    1
# 20.00    1
# 22.00    1
# 7.30     1
# 9.00     1
# 17.20    1
# 5.00     1
# 19.30    1
# 22.30    1
# 14.00    1
# 13.00    1
# 17.30    1
# 11.00    1
# 5.30     1
# 8.15     1
# 10.20    1
# 18.30    1
# 12.35    1
# 15.10    1
# 18.20    1
# 20.25    1
# 22.40    1
# 10.25    1
# 12.50    1
# 15.15    1
# 20.35    1
# 6.00     1
# 22.50    1
# 8.20     1
# 10.15    1
# 12.30    1
# 15.05    1
# 18.15    1
# 20.20    1
# 22.35    1
# 21.00    1
# Name: count, dtype: int64

# %%
time_ = data[' time']
passengers_ = data[' passengers']
ride_time_min_ = data[' ride_time_min']
cost_per_ride_ = data[' cost_per_ride']
income_per_ride_ = data[' income_per_ride']
profit_per_ride_ = data[' profit_per_ride']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

from sklearn import metrics

from matplotlib import style

style.use('ggplot')
fig = plt.figure(figsize=(20, 5))
fig.suptitle('Visualizing categorical data columns')
plt.subplot(1,3,1)
plt.bar(time_,passengers_, color='royalblue')
plt.xlabel("Time(Hours)")
plt.ylabel("Passengers")
plt.subplot(1,3,2)
plt.bar(ride_time_min_,cost_per_ride_, color='red')
plt.xlabel("Time(Minutes)")
plt.ylabel("Cost Per Ride(Rs)")
plt.subplot(1,3,3)
plt.bar(profit_per_ride_,cost_per_ride_, color='red')
plt.xlabel("Profit Per Ride(Rs)")
plt.ylabel("Cost Per Ride(Rs)")
plt.show()

# %%
data
# Out:
#           date   time   bus_rides_per_day   distance_km   passengers
# 0   2023-03-01   8.15                   8            20           30  \
# 1   2023-03-01  10.20                   8            20           28
# 2   2023-03-01  12.35                   8            20           32
# 3   2023-03-01  15.10                   8            20           26
# 4   2023-03-01  18.20                   8            20           33
# 5   2023-03-01  20.25                   8            20           31
# 6   2023-03-01  22.40                   8            20           27
# 7   2023-03-01  23.55                   8            20           29
# 8   2023-03-02   8.10                   8            20           32
# 9   2023-03-02  10.25                   8            20           30
# 10  2023-03-02  12.50                   8            20           28
# 11  2023-03-02  15.15                   8            20           31
# 12  2023-03-02  18.30                   8            20           29
# ...

# %%
import requests
import pandas as pd
import io
url = "https://raw.githubusercontent.com/Samithuiit/ML-SDGP/main/bus_data.csv"
response = requests.get(url)
content = response.content.decode('utf-8')
data = pd.read_csv(io.StringIO(content))
data.head()
# Out:
#          date   time   bus_rides_per_day   distance_km   passengers
# 0  2023-03-01   8.15                   8            20           30  \
# 1  2023-03-01  10.20                   8            20           28
# 2  2023-03-01  12.35                   8            20           32
# 3  2023-03-01  15.10                   8            20           26
# 4  2023-03-01  18.20                   8            20           33
#
#     ride_time_min   income_per_ride   cost_per_ride   profit_per_ride
# 0              40            8000.0          3500.0            4500.0
# 1              35            8500.0          3600.0            4900.0
# 2              42            7900.0          3550.0            4350.0
# 3              45            9000.0          3700.0            5300.0
# 4              38            8100.0          3550.0            4550.0

# %%
data
# Out:
#           date   time   bus_rides_per_day   distance_km   passengers
# 0   2023-03-01   8.15                   8            20           30  \
# 1   2023-03-01  10.20                   8            20           28
# 2   2023-03-01  12.35                   8            20           32
# 3   2023-03-01  15.10                   8            20           26
# 4   2023-03-01  18.20                   8            20           33
# 5   2023-03-01  20.25                   8            20           31
# 6   2023-03-01  22.40                   8            20           27
# 7   2023-03-01  23.55                   8            20           29
# 8   2023-03-02   8.10                   8            20           32
# 9   2023-03-02  10.25                   8            20           30
# 10  2023-03-02  12.50                   8            20           28
# 11  2023-03-02  15.15                   8            20           31
# 12  2023-03-02  18.30                   8            20           29
# ...

# %%
data.describe()
# Out:
#             time   bus_rides_per_day   distance_km   passengers
# count  56.000000                56.0          56.0    56.000000  \
# mean   15.130357                 8.0          20.0    32.839286
# std     5.547519                 0.0           0.0     5.496368
# min     5.000000                 8.0          20.0    20.000000
# 25%    10.287500                 8.0          20.0    29.000000
# 50%    15.025000                 8.0          20.0    31.500000
# 75%    20.050000                 8.0          20.0    36.250000
# max    23.550000                 8.0          20.0    45.000000
#
#         ride_time_min   income_per_ride   cost_per_ride   profit_per_ride
# count       56.000000         56.000000       56.000000         56.000000
# mean        40.446429       8650.000000     3557.767857       5099.375000
# std          4.343939        744.006354      105.360505        718.937387
# min         30.000000       6500.000000     3300.000000       3200.000000
# ...

# %%
time_ = data[' time']
passengers_ = data[' passengers']
ride_time_min_ = data[' ride_time_min']
cost_per_ride_ = data[' cost_per_ride']
income_per_ride_ = data[' income_per_ride']
profit_per_ride_ = data[' profit_per_ride']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

from sklearn import metrics

from matplotlib import style

style.use('ggplot')
fig = plt.figure(figsize=(20, 5))
fig.suptitle('Visualizing categorical data columns')
plt.subplot(1,3,1)
plt.bar(time_,passengers_, color='royalblue')
plt.xlabel("Time(Hours)")
plt.ylabel("Passengers")
plt.subplot(1,3,2)
plt.bar(ride_time_min_,cost_per_ride_, color='red')
plt.xlabel("Time(Minutes)")
plt.ylabel("Cost Per Ride(Rs)")
plt.subplot(1,3,3)
plt.bar(profit_per_ride_,cost_per_ride_, color='red')
plt.xlabel("Profit Per Ride(Rs)")
plt.ylabel("Cost Per Ride(Rs)")
plt.show()

# %%
fig, axes = plt.subplots(1,3,figsize=(15,5), sharey=True)
fig.suptitle('Visualizing categorical columns')
sns.barplot(x=time_, y=cost_per_ride_, ax=axes[0])
sns.barplot(x=ride_time_min_, y=cost_per_ride_, ax=axes[1])
sns.barplot(x=profit_per_ride_, y=cost_per_ride_, ax=axes[2])
# Out:
# <Axes: xlabel=' profit_per_ride', ylabel=' cost_per_ride'>

# %%
data['date'] = pd.to_datetime(data['date'])
plt.figure(figsize=(10,7))
sns.heatmap(data.corr(), annot=True)
plt.title('Co-relation between the columns')
plt.show()

# %%
fig=plt.figure(figsize=(7,5))
plt.title('Correlation between passengers and Profit')
sns.regplot(x=' time', y=' profit_per_ride', data=data)
# Out:
# <Axes: title={'center': 'Correlation between passengers and Profit'}, xlabel=' time', ylabel=' profit_per_ride'>

# %%
fig=plt.figure(figsize=(7,5))
plt.title('Correlation between passengers and time')
sns.regplot(x=' time', y=' passengers', data=data)
# Out:
# <Axes: title={'center': 'Correlation between passengers and time'}, xlabel=' time', ylabel=' passengers'>

# %%
fig=plt.figure(figsize=(7,5))
plt.title('Correlation between income and profit')
sns.regplot(x=' income_per_ride', y=' profit_per_ride', data=data)
# Out:
# <Axes: title={'center': 'Correlation between income and profit'}, xlabel=' income_per_ride', ylabel=' profit_per_ride'>

# %%
fig=plt.figure(figsize=(7,5))
plt.title('Correlation between cost and income')
sns.regplot(x=' cost_per_ride', y=' income_per_ride', data=data)
# Out:
# <Axes: title={'center': 'Correlation between cost and income'}, xlabel=' cost_per_ride', ylabel=' income_per_ride'>

# %%
fig=plt.figure(figsize=(7,5))
plt.title('Correlation between cost and profit')
sns.regplot(x=' cost_per_ride', y=' profit_per_ride', data=data)
# Out:
# <Axes: title={'center': 'Correlation between cost and profit'}, xlabel=' cost_per_ride', ylabel=' profit_per_ride'>

# %%
fig=plt.figure(figsize=(7,5))
plt.title('Correlation between cost and time')
sns.regplot(x=' cost_per_ride', y=' time', data=data)
# Out:
# <Axes: title={'center': 'Correlation between cost and time'}, xlabel=' cost_per_ride', ylabel=' time'>

# %%
fig=plt.figure(figsize=(7,5))
plt.title('Correlation between cost and passengers')
sns.regplot(x=' cost_per_ride', y=' passengers', data=data)
# Out:
# <Axes: title={'center': 'Correlation between cost and passengers'}, xlabel=' cost_per_ride', ylabel=' passengers'>

# %%
data.describe()
# Out:
#             time   bus_rides_per_day   distance_km   passengers
# count  56.000000                56.0          56.0    56.000000  \
# mean   15.130357                 8.0          20.0    32.839286
# std     5.547519                 0.0           0.0     5.496368
# min     5.000000                 8.0          20.0    20.000000
# 25%    10.287500                 8.0          20.0    29.000000
# 50%    15.025000                 8.0          20.0    31.500000
# 75%    20.050000                 8.0          20.0    36.250000
# max    23.550000                 8.0          20.0    45.000000
#
#         ride_time_min   income_per_ride   cost_per_ride   profit_per_ride
# count       56.000000         56.000000       56.000000         56.000000
# mean        40.446429       8650.000000     3557.767857       5099.375000
# std          4.343939        744.006354      105.360505        718.937387
# min         30.000000       6500.000000     3300.000000       3200.000000
# ...

# %%
x = data.drop([' ride_time_min',' profit_per_ride'], axis=1) 
y = data[' profit_per_ride']

# %%
print("Shape of X is: ",x.shape)
print("Shape of y is: ",y.shape)
# Out:
# Shape of X is:  (56, 6)
# Shape of y is:  (56,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state =42)

# %%
print("x_test shape:", x_test.shape)
print("x_train shape:", x_train.shape)
print("y_test shape:", y_test.shape)
print("y_train shape:", y_train.shape)
# Out:
# x_test shape: (17, 6)
# x_train shape: (39, 6)
# y_test shape: (17,)
# y_train shape: (39,)

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
print("MAE: ", (metrics.mean_absolute_error(pred, y_test)))
print("MSE: ", (metrics.mean_squared_error(pred, y_test)))
print("R2 score: ", (metrics.r2_score(pred, y_test)))
# Out:
# MAE:  30.785431981583905
# MSE:  1393.4821291445187
# R2 score:  0.9965309082802508

# %%
sns.regplot(x=pred, y=y_test)
plt.xlabel("predicted profit")
plt.ylabel("actual vs predict profit")
plt.show()
